# %%
import requests
import json

base_url = 'http://nomad-lab.eu/prod/v1/api/v1'

response = requests.post(
    f'{base_url}/entries/query',
    json={
        'query': {
            'results.material.elements': {
                'all': ['Ti', 'O']
            }
        },
        'pagination': {
            'page_size': 1
        },
        'required': {
            "run": {
                "configuration": {
                    "energy": "energy_total"
                }
            }
        }
    })
response_json = response.json()
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "owner": "public",
#   "query": {
#     "name": "results.material.elements",
#     "value": {
#       "all": [
#         "Ti",
#         "O"
#       ]
#     }
#   },
#   "pagination": {
#     "page_size": 1,
#     "order_by": "entry_id",
#     "order": "asc",
#     "total": 24111,
#     "next_page_after_value": "--SZVYOxA2jTu_L-mSxefSQFmeyF"
#   },
#   "required": {},
#   "data": [
#     {
#       "upload_id": "YXUIZpw5RJyV3LAsFI2MmQ",
#       "references": [],
#       "origin": "Aliaksei Mazheika",
#       "quantities": [
#         "",
#         ".metadata",
#         ".results",
#         ".run",
#         ".workflow",
#         "metadata",
#         "metadata.calc_hash",
#         "metadata.calc_id",
#         "metadata.coauthors",
#         "metadata.datasets",
#         "metadata.domain",
#         "metadata.embargo_length",
#         "metadata.entry_coauthors",
#         "metadata.entry_create_time",
#         "metadata.files",
#         "metadata.last_processing_time",
#         "metadata.license",
#         "metadata.main_author",
#         "metadata.mainfile",
#         "metadata.nomad_commit",
#         "metadata.nomad_version",
#         "metadata.optimade",
#         "metadata.optimade.cartesian_site_positions",
#         "metadata.optimade.chemical_formula_anonymous",
#         "metadata.optimade.chemical_formula_descriptive",
#         "metadata.optimade.chemical_formula_hill",
#         "metadata.optimade.chemical_formula_reduced",
#         "metadata.optimade.dimension_types",
#         "metadata.optimade.elements",
#         "metadata.optimade.elements_ratios",
#         "metadata.optimade.lattice_vectors",
#         "metadata.optimade.nelements",
#         "metadata.optimade.nsites",
#         "metadata.optimade.species",
#         "metadata.optimade.species.chemical_symbols",
#         "metadata.optimade.species.concentration",
#         "metadata.optimade.species.name",
#         "metadata.optimade.species_at_sites",
#         "metadata.optimade.structure_features",
#         "metadata.parser_name",
#         "metadata.pid",
#         "metadata.processed",
#         "metadata.processing_errors",
#         "metadata.publish_time",
#         "metadata.published",
#         "metadata.references",
#         "metadata.reviewers",
#         "metadata.upload_create_time",
#         "metadata.upload_id",
#         "metadata.upload_name",
#         "metadata.with_embargo",
#         "results",
#         "results.material",
#         "results.material.chemical_formula_anonymous",
#         "results.material.chemical_formula_descriptive",
#         "results.material.chemical_formula_hill",
#         "results.material.chemical_formula_reduced",
#         "results.material.chemical_formula_reduced_fragments",
#         "results.material.elements",
#         "results.material.structural_type",
#         "results.method",
#         "results.method.method_name",
#         "results.method.simulation",
#         "results.method.simulation.dft",
#         "results.method.simulation.dft.basis_set_type",
#         "results.method.simulation.dft.core_electron_treatment",
#         "results.method.simulation.dft.relativity_method",
#         "results.method.simulation.dft.spin_polarized",
#         "results.method.simulation.dft.xc_functional_names",
#         "results.method.simulation.dft.xc_functional_type",
#         "results.method.simulation.geometry_optimization",
#         "results.method.simulation.geometry_optimization.type",
#         "results.method.simulation.program_name",
#         "results.method.simulation.program_version",
#         "results.properties",
#         "results.properties.available_properties",
#         "results.properties.geometry_optimization",
#         "results.properties.geometry_optimization.energies",
#         "results.properties.geometry_optimization.structure_optimized",
#         "results.properties.geometry_optimization.structure_optimized.atomic_density",
#         "results.properties.geometry_optimization.structure_optimized.cartesian_site_positions",
#         "results.properties.geometry_optimization.structure_optimized.cell_volume",
#         "results.properties.geometry_optimization.structure_optimized.dimension_types",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.a",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.alpha",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.b",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.beta",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.c",
#         "results.properties.geometry_optimization.structure_optimized.lattice_parameters.gamma",
#         "results.properties.geometry_optimization.structure_optimized.lattice_vectors",
#         "results.properties.geometry_optimization.structure_optimized.mass_density",
#         "results.properties.geometry_optimization.structure_optimized.species",
#         "results.properties.geometry_optimization.structure_optimized.species.chemical_symbols",
#         "results.properties.geometry_optimization.structure_optimized.species.concentration",
#         "results.properties.geometry_optimization.structure_optimized.species.name",
#         "results.properties.geometry_optimization.structure_optimized.species_at_sites",
#         "results.properties.geometry_optimization.trajectory",
#         "results.properties.n_calculations",
#         "results.properties.structures",
#         "results.properties.structures.structure_original",
#         "results.properties.structures.structure_original.atomic_density",
#         "results.properties.structures.structure_original.cartesian_site_positions",
#         "results.properties.structures.structure_original.cell_volume",
#         "results.properties.structures.structure_original.dimension_types",
#         "results.properties.structures.structure_original.lattice_parameters",
#         "results.properties.structures.structure_original.lattice_parameters.a",
#         "results.properties.structures.structure_original.lattice_parameters.alpha",
#         "results.properties.structures.structure_original.lattice_parameters.b",
#         "results.properties.structures.structure_original.lattice_parameters.beta",
#         "results.properties.structures.structure_original.lattice_parameters.c",
#         "results.properties.structures.structure_original.lattice_parameters.gamma",
#         "results.properties.structures.structure_original.lattice_vectors",
#         "results.properties.structures.structure_original.mass_density",
#         "results.properties.structures.structure_original.species",
#         "results.properties.structures.structure_original.species.chemical_symbols",
#         "results.properties.structures.structure_original.species.concentration",
#         "results.properties.structures.structure_original.species.name",
#         "results.properties.structures.structure_original.species_at_sites",
#         "run",
#         "run.calculation",
#         "run.calculation.calculation_converged",
#         "run.calculation.eigenvalues",
#         "run.calculation.eigenvalues.energies",
#         "run.calculation.eigenvalues.kpoints",
#         "run.calculation.eigenvalues.occupations",
#         "run.calculation.energy",
#         "run.calculation.energy.correction_entropy",
#         "run.calculation.energy.correction_entropy.value",
#         "run.calculation.energy.correction_hartree",
#         "run.calculation.energy.correction_hartree.value",
#         "run.calculation.energy.correction_xc",
#         "run.calculation.energy.correction_xc.value",
#         "run.calculation.energy.correlation",
#         "run.calculation.energy.correlation.value",
#         "run.calculation.energy.exchange",
#         "run.calculation.energy.exchange.value",
#         "run.calculation.energy.fermi",
#         "run.calculation.energy.free",
#         "run.calculation.energy.free.value",
#         "run.calculation.energy.hartree_fock_x_scaled",
#         "run.calculation.energy.hartree_fock_x_scaled.value",
#         "run.calculation.energy.sum_eigenvalues",
#         "run.calculation.energy.sum_eigenvalues.value",
#         "run.calculation.energy.total",
#         "run.calculation.energy.total.value",
#         "run.calculation.energy.total_t0",
#         "run.calculation.energy.total_t0.value",
#         "run.calculation.energy.xc",
#         "run.calculation.energy.xc.value",
#         "run.calculation.energy.xc_potential",
#         "run.calculation.energy.xc_potential.value",
#         "run.calculation.method_ref",
#         "run.calculation.n_scf_iterations",
#         "run.calculation.scf_iteration",
#         "run.calculation.scf_iteration.eigenvalues",
#         "run.calculation.scf_iteration.eigenvalues.energies",
#         "run.calculation.scf_iteration.eigenvalues.kpoints",
#         "run.calculation.scf_iteration.eigenvalues.occupations",
#         "run.calculation.scf_iteration.energy",
#         "run.calculation.scf_iteration.energy.change",
#         "run.calculation.scf_iteration.energy.correction_entropy",
#         "run.calculation.scf_iteration.energy.correction_entropy.value",
#         "run.calculation.scf_iteration.energy.correction_hartree",
#         "run.calculation.scf_iteration.energy.correction_hartree.value",
#         "run.calculation.scf_iteration.energy.correction_xc",
#         "run.calculation.scf_iteration.energy.correction_xc.value",
#         "run.calculation.scf_iteration.energy.fermi",
#         "run.calculation.scf_iteration.energy.free",
#         "run.calculation.scf_iteration.energy.free.value",
#         "run.calculation.scf_iteration.energy.sum_eigenvalues",
#         "run.calculation.scf_iteration.energy.sum_eigenvalues.value",
#         "run.calculation.scf_iteration.energy.total",
#         "run.calculation.scf_iteration.energy.total.value",
#         "run.calculation.scf_iteration.energy.total_t0",
#         "run.calculation.scf_iteration.energy.total_t0.value",
#         "run.calculation.scf_iteration.energy.xc_potential",
#         "run.calculation.scf_iteration.energy.xc_potential.value",
#         "run.calculation.scf_iteration.x_fhi_aims_scf_date_start",
#         "run.calculation.scf_iteration.x_fhi_aims_scf_time_start",
#         "run.calculation.system_ref",
#         "run.calculation.x_fhi_aims_energy_C_LDA",
#         "run.calculation.x_fhi_aims_energy_X_LDA",
#         "run.method",
#         "run.method.atom_parameters",
#         "run.method.atom_parameters.charge",
#         "run.method.atom_parameters.label",
#         "run.method.atom_parameters.mass",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_charge",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_cut_pot",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_cut_pot_scale",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_cut_pot_width",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_mass",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_controlInOut_species_name",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func.x_fhi_aims_controlInOut_basis_func_eff_charge",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func.x_fhi_aims_controlInOut_basis_func_l",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func.x_fhi_aims_controlInOut_basis_func_n",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func.x_fhi_aims_controlInOut_basis_func_occ",
#         "run.method.atom_parameters.x_fhi_aims_section_controlInOut_atom_species.x_fhi_aims_section_controlInOut_basis_func.x_fhi_aims_controlInOut_basis_func_type",
#         "run.method.basis_set",
#         "run.method.basis_set.type",
#         "run.method.core_method_ref",
#         "run.method.dft",
#         "run.method.dft.xc_functional",
#         "run.method.dft.xc_functional.correlation",
#         "run.method.dft.xc_functional.correlation.name",
#         "run.method.dft.xc_functional.exchange",
#         "run.method.dft.xc_functional.exchange.name",
#         "run.method.dft.xc_functional.name",
#         "run.method.electronic",
#         "run.method.electronic.method",
#         "run.method.electronic.n_spin_channels",
#         "run.method.electronic.relativity_method",
#         "run.method.methods_ref",
#         "run.method.x_fhi_aims_controlInOut_k_grid",
#         "run.method.x_fhi_aims_controlInOut_number_of_spin_channels",
#         "run.method.x_fhi_aims_controlInOut_relativistic",
#         "run.method.x_fhi_aims_controlInOut_xc",
#         "run.method.x_fhi_aims_controlIn_k_grid",
#         "run.method.x_fhi_aims_controlIn_occupation_type",
#         "run.method.x_fhi_aims_controlIn_occupation_width",
#         "run.method.x_fhi_aims_controlIn_relativistic",
#         "run.method.x_fhi_aims_controlIn_sc_accuracy_eev",
#         "run.method.x_fhi_aims_controlIn_sc_accuracy_etot",
#         "run.method.x_fhi_aims_controlIn_sc_accuracy_rho",
#         "run.method.x_fhi_aims_controlIn_sc_iter_limit",
#         "run.method.x_fhi_aims_controlIn_spin",
#         "run.method.x_fhi_aims_controlIn_xc",
#         "run.method.x_fhi_aims_section_controlIn_basis_set",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_angular_grids_method",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_basis_dep_cutoff",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_cut_pot",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_division",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_l_hartree",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_mass",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_nucleus",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_number_of_basis_func",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_outer_grid",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_radial_base",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_radial_multiplier",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_controlIn_species_name",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_section_controlIn_basis_func",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_section_controlIn_basis_func.x_fhi_aims_controlIn_basis_func_l",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_section_controlIn_basis_func.x_fhi_aims_controlIn_basis_func_n",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_section_controlIn_basis_func.x_fhi_aims_controlIn_basis_func_radius",
#         "run.method.x_fhi_aims_section_controlIn_basis_set.x_fhi_aims_section_controlIn_basis_func.x_fhi_aims_controlIn_basis_func_type",
#         "run.program",
#         "run.program.compilation_host",
#         "run.program.name",
#         "run.program.version",
#         "run.system",
#         "run.system.atoms",
#         "run.system.atoms.labels",
#         "run.system.atoms.lattice_vectors",
#         "run.system.atoms.periodic",
#         "run.system.atoms.positions",
#         "run.system.atoms.species",
#         "run.system.chemical_composition",
#         "run.system.chemical_composition_hill",
#         "run.system.chemical_composition_reduced",
#         "run.system.configuration_raw_gid",
#         "run.system.is_representative",
#         "run.system.type",
#         "run.time_run",
#         "run.time_run.cpu1_start",
#         "run.time_run.wall_start",
#         "run.x_fhi_aims_number_of_tasks",
#         "run.x_fhi_aims_program_compilation_date",
#         "run.x_fhi_aims_program_compilation_time",
#         "run.x_fhi_aims_program_execution_date",
#         "run.x_fhi_aims_program_execution_time",
#         "run.x_fhi_aims_section_parallel_tasks",
#         "run.x_fhi_aims_section_parallel_tasks.x_fhi_aims_section_parallel_task_assignement",
#         "run.x_fhi_aims_section_parallel_tasks.x_fhi_aims_section_parallel_task_assignement.x_fhi_aims_parallel_task_host",
#         "run.x_fhi_aims_section_parallel_tasks.x_fhi_aims_section_parallel_task_assignement.x_fhi_aims_parallel_task_nr",
#         "workflow",
#         "workflow.calculation_result_ref",
#         "workflow.calculations_ref",
#         "workflow.geometry_optimization",
#         "workflow.geometry_optimization.energies",
#         "workflow.geometry_optimization.optimization_steps",
#         "workflow.geometry_optimization.type",
#         "workflow.type"
#       ],
#       "pid": "3318659",
#       "datasets": [],
#       "n_quantities": 15093,
#       "nomad_version": "1.0.0",
#       "upload_create_time": "2017-02-16T19:36:09.331000",
#       "nomad_commit": "37587aa6",
#       "publish_time": "2017-02-16T19:36:09.331000",
#       "processing_errors": [],
#       "results": {
#         "material": {
#           "elements": [
#             "F",
#             "O",
#             "Sr",
#             "Ti"
#           ],
#           "elements_exclusive": "F O Sr Ti",
#           "chemical_formula_anonymous": "A9B3C3D2",
#           "structural_type": "surface",
#           "chemical_formula_reduced": "F2O9Sr3Ti3",
#           "n_elements": 4,
#           "chemical_formula_descriptive": "F2O9Sr3Ti3",
#           "chemical_formula_reduced_fragments": [
#             "F2",
#             "O9",
#             "Sr3",
#             "Ti3"
#           ],
#           "chemical_formula_hill": "F2O9Sr3Ti3"
#         },
#         "method": {
#           "method_name": "DFT",
#           "simulation": {
#             "program_version": "150205",
#             "dft": {
#               "basis_set_type": "numeric AOs",
#               "core_electron_treatment": "full all electron",
#               "xc_functional_type": "GGA",
#               "xc_functional_names": [
#                 "GGA_C_PBE",
#                 "GGA_X_PBE"
#               ],
#               "spin_polarized": true,
#               "relativity_method": "scalar_relativistic_atomic_ZORA"
#             },
#             "program_name": "FHI-aims"
#           }
#         },
#         "properties": {
#           "available_properties": [
#             "geometry_optimization"
#           ],
#           "n_calculations": 1,
#           "structures": {
#             "structure_original": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 17,
#               "cell_volume": 5.5087531974999976e-27,
#               "lattice_parameters": {
#                 "a": 3.9473e-10,
#                 "b": 5.5823e-10,
#                 "c": 2.5000000000000002e-08,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.5707963267948966
#               }
#             }
#           },
#           "geometry_optimization": {
#             "structure_optimized": {
#               "nperiodic_dimensions": 3,
#               "n_sites": 17,
#               "cell_volume": 5.5087531974999976e-27,
#               "lattice_parameters": {
#                 "a": 3.9473e-10,
#                 "b": 5.5823e-10,
#                 "c": 2.5000000000000002e-08,
#                 "alpha": 1.5707963267948966,
#                 "beta": 1.5707963267948966,
#                 "gamma": 1.5707963267948966
#               }
#             }
#           }
#         }
#       },
#       "last_processing_time": "2022-01-03T23:30:12.446000",
#       "optimade": {
#         "nperiodic_dimensions": 3,
#         "species_at_sites": [
#           "O",
#           "O",
#           "Sr",
#           "Ti",
#           "O",
#           "O",
#           "O",
#           "Sr",
#           "Ti",
#           "O",
#           "O",
#           "O",
#           "Sr",
#           "Ti",
#           "O",
#           "F",
#           "F"
#         ],
#         "nsites": 17,
#         "elements": [
#           "F",
#           "O",
#           "Sr",
#           "Ti"
#         ],
#         "chemical_formula_anonymous": "A9B3C3D2",
#         "chemical_formula_reduced": "F2O9Sr3Ti3",
#         "structure_features": [],
#         "nelements": 4,
#         "chemical_formula_descriptive": "F2O9Sr3Ti3",
#         "chemical_formula_hill": "F2O9Sr3Ti3",
#         "elements_ratios": [
#           [
#             {
#               "elements": "F",
#               "elements_ratios": 0.11764705882352941
#             },
#             {
#               "elements": "O",
#               "elements_ratios": 0.5294117647058824
#             },
#             {
#               "elements": "Sr",
#               "elements_ratios": 0.17647058823529413
#             },
#             {
#               "elements": "Ti",
#               "elements_ratios": 0.17647058823529413
#             }
#           ],
#           [
#             {
#               "elements": "F",
#               "elements_ratios": 0.11764705882352941
#             },
#             {
#               "elements": "O",
#               "elements_ratios": 0.5294117647058824
#             },
#             {
#               "elements": "Sr",
#               "elements_ratios": 0.17647058823529413
#             },
#             {
#               "elements": "Ti",
#               "elements_ratios": 0.17647058823529413
#             }
#           ],
#           [
#             {
#               "elements": "F",
#               "elements_ratios": 0.11764705882352941
#             },
#             {
#               "elements": "O",
#               "elements_ratios": 0.5294117647058824
#             },
#             {
#               "elements": "Sr",
#               "elements_ratios": 0.17647058823529413
#             },
#             {
#               "elements": "Ti",
#               "elements_ratios": 0.17647058823529413
#             }
#           ],
#           [
#             {
#               "elements": "F",
#               "elements_ratios": 0.11764705882352941
#             },
#             {
#               "elements": "O",
#               "elements_ratios": 0.5294117647058824
#             },
#             {
#               "elements": "Sr",
#               "elements_ratios": 0.17647058823529413
#             },
#             {
#               "elements": "Ti",
#               "elements_ratios": 0.17647058823529413
#             }
#           ]
#         ]
#       },
#       "parser_name": "parsers/fhi-aims",
#       "calc_id": "--SZVYOxA2jTu_L-mSxefSQFmeyF",
#       "published": true,
#       "writers": [
#         {
#           "user_id": "b909b290-a264-4e52-914f-eb443f801248",
#           "name": "Aliaksei Mazheika"
#         }
#       ],
#       "processed": true,
#       "mainfile": "SrTiO3/110/O-top/surface_charge/F-termin/2F+0.15/PBE-light+tight-rho2.out",
#       "main_author": {
#         "user_id": "b909b290-a264-4e52-914f-eb443f801248",
#         "name": "Aliaksei Mazheika"
#       },
#       "viewers": [
#         {
#           "user_id": "b909b290-a264-4e52-914f-eb443f801248",
#           "name": "Aliaksei Mazheika"
#         }
#       ],
#       "entry_create_time": "2019-05-07T04:38:25",
#       "with_embargo": false,
#       "domain": "dft",
#       "files": [
#         "SrTiO3/110/O-top/surface_charge/F-termin/2F+0.15/PBE-light+tight-rho2.out",
#         "SrTiO3/110/O-top/surface_charge/F-termin/2F+0.15/control.in",
#         "SrTiO3/110/O-top/surface_charge/F-termin/2F+0.15/geometry.in"
#       ],
#       "entry_id": "--SZVYOxA2jTu_L-mSxefSQFmeyF",
#       "upload_name": "Y1jCLQ-nTaiijkV4ORs2NA",
#       "authors": [
#         {
#           "user_id": "b909b290-a264-4e52-914f-eb443f801248",
#           "name": "Aliaksei Mazheika"
#         }
#       ],
#       "license": "CC BY 4.0"
#     }
#   ]
# }

# %%
print(response_json['data'][3]['entry_id'])
# Out:
# --bsrIMI2JBDNMK2O0butFvHzXki

# %%
first_entry_id = response_json['data'][3]['entry_id']
response = requests.post(
    f'{base_url}/entries/{first_entry_id}/archive/query',
    json={
        'required': {
            'workflow': {
                'calculation_result_ref': {
                    'energy': '*',
                    'system_ref': {
                        'chemical_composition': '*'
                    }
                }
            }
        }
    })
response_json = response.json()
print(json.dumps(response_json, indent=2))
# Out:
# {
#   "required": {
#     "workflow": {
#       "calculation_result_ref": {
#         "energy": "*",
#         "system_ref": {
#           "chemical_composition": "*"
#         }
#       }
#     }
#   },
#   "entry_id": "--bsrIMI2JBDNMK2O0butFvHzXki",
#   "data": {
#     "entry_id": "--bsrIMI2JBDNMK2O0butFvHzXki",
#     "upload_id": "kOB1YOl2T9Wq-q4EBcYT0A",
#     "parser_name": "parsers/fhi-aims",
#     "archive": {
#       "run": [
#         {
#           "system": [
#             {
#               "chemical_composition": "..."
#             }
#           ],
#           "calculation": [
#             {
#               "energy": {
#                 "fermi": 0.0,
#                 "total": {
#                   "value": -2.3363424167443618e-12
#                 },
#                 "exchange": {
#                   "value": -9.255916599710068e-14
#                 },
#                 "xc": {
#                   "value": -9.457337544435541e-14
#                 },
#                 "xc_potential": {
#                   "value": 1.2278854433234209e-13
#                 },
#                 "free": {
#                   "value": -2.3363424167443618e-12
#                 },
#                 "sum_eigenvalues": {
#                   "value": -1.3913806131259732e-12
#                 },
#                 "total_t0": {
#                   "value": -2.3363424167443618e-12
#                 },
#                 "van_der_waals": {
#                   "kind": "Tkatchenko/Scheffler 2009",
#                   "value": -3.974469987305428e-17
#                 },
#                 "correction_entropy": {
#                   "value": 0.0
#                 },
#                 "correction_hartree": {
#                   "value": 4.294753926541976e-16
#                 },
#                 "correction_xc": {
#                   "value": -9.457337544435541e-14
#                 }
#               },
#               "system_ref": "/run/0/system/0"
#             }
#           ]
#         }
#       ],
#       "workflow": [
#         {
#           "calculation_result_ref": "/run/0/calculation/0"
#         }
#       ],
#       "m_ref_archives": {}
#     }
#   }
# }

# %%
response = requests.post(
    f'{base_url}/entries/query',
    json={
        'query': {
            "results.properties.electronic.band_structure_electronic.band_gap": {
              "type:any": [
                "direct"
              ],
              "value": {
                "gte": 4.085759767784399e-19,
                "lte": 2.3134258869804897e-18
              }
            }
        },
        'pagination': {
            'page_size': 5
        },
        'required': {
            "results": {
                "material": {
                    "chemical_formula_reduced": "*"
                }
            }
        }
    })

response_json = response.json()

#print(json.dumps(response.json(), indent=2))
for entry in response_json['data']:
    print(entry['entry_id'])
    print(entry['results']['material']['chemical_formula_reduced'])
# Out:
# --0ttXeSYjWlLRMm2OIrzujNOxCb
# H4Li4
# --7EO2Q1exqlLBm9dImG4WKJybsk
# ClLi
# --Hz0U6YpO691ha6_CatQ0KrhOjJ
# Ca4O4
# --_npCChxBlIE3bkLaawtkngnEkS
# ClCs
# --b--AqROml19cw86rZ748lzPkQY
# ClCs
